# %%
import pandas as pd

# load model
featuresdf = pd.read_pickle('./data_processed/featuresData')
print(featuresdf)
# Out:
#                                                feature class_label
# 0    [[-677.2284, -675.868, -604.5181, -508.6319, -...        fear
# 1    [[-541.3354, -500.66827, -471.35553, -459.4574...       happy
# 2    [[-692.65314, -644.6554, -568.15466, -515.6153...         sad
# 3    [[-681.12274, -651.9668, -525.6198, -443.5369,...        fear
# 4    [[-655.34607, -582.11316, -496.3355, -432.5717...       happy
# ..                                                 ...         ...
# 595  [[-700.8672, -633.0773, -548.29913, -492.718, ...       happy
# 596  [[-550.38446, -509.70435, -474.91278, -453.879...         sad
# 597  [[-533.8698, -473.1169, -420.50345, -391.5591,...        fear
# 598  [[-667.7516, -631.7557, -551.61646, -502.2961,...       happy
# 599  [[-761.32166, -732.29486, -638.62305, -572.652...         sad
#
# [600 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
import numpy as np


# pick features and classes
X = np.array(featuresdf.feature.tolist())
y = np.array(featuresdf.class_label.tolist())

# codify classes in [[0,1,0,0..,0], ..., [0,0,1,0..,0]]
le = LabelEncoder()
yy = to_categorical(le.fit_transform(y)) 

# split the dataset 
from sklearn.model_selection import train_test_split 

x_train, x_test, y_train, y_test = train_test_split(X, yy, test_size=0.2, random_state = 17)

# confirm shape of data's
print("size of x_train: ", x_train.shape)
print("size of x_test: ", x_test.shape)
print("\nsize of y_train: ", y_train.shape)
print("size of y_test: ", y_test.shape)
# Out:
# size of x_train:  (480, 40, 174)
# size of x_test:  (120, 40, 174)
#
# size of y_train:  (480, 3)
# size of y_test:  (120, 3)

# %%
# CNN IMPLEMENTATION (sklearn and keras)

# sequential model with 3 Conv2D and 1 dense layer as final
# convolution layers will detect features based on window slice (filters and multiplex matrix)
# the result will be stored in features map

# if kernel_size or window_size is 2, it results in a 2x2 matrix that grows in 16, 32, 64, 128...

# first layer recieves:
# < MFCC'S number, max_pad_len, audio (1 for mono, 2 for stereo)>

# ReLU for activation function

# Dropout defines the learning speed after each layer

# after each convolutional layer, there's a pooling (MaxPooling2D) layer
# the final layer haves a GlobalAveragePooling2D.
# pooling is used for reduce the input, reducing the training timming
# MaxPooling pick the highest value in window
# Global Average Pooling pick the mean to use in final dense layer

# the final layer has nodes in the same number of types of class
# softmax pick the best probability, set 1 to it and 0 for others

from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.utils import np_utils
from sklearn import metrics 


# parameters
num_rows = 40
num_columns = 174
num_channels = 1
filter_size = 2

# reshape the features
x_train = x_train.reshape(x_train.shape[0], num_rows, num_columns, num_channels)
x_test = x_test.reshape(x_test.shape[0], num_rows, num_columns, num_channels)

# pick number of classes
num_labels = yy.shape[1]

# type of model
model = Sequential()

# convolution layers
model.add(Conv2D(filters=16, kernel_size=filter_size, input_shape=(num_rows, num_columns, num_channels), 
                 activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=32, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

#model.add(Conv2D(filters=128, kernel_size=filter_size, activation='relu'))
#model.add(MaxPooling2D(pool_size=2))
#model.add(Dropout(0.1))
model.add(GlobalAveragePooling2D())

# final dense layer
model.add(Dense(num_labels, activation='softmax')) 

print("model created!")
print("\npatern: <num_rows, num_columns, num_channels>")
print("input shape: < {} , {} , {} >".format(num_rows, num_columns, num_channels))
print("\nfilter size:", filter_size)
# Out:
# model created!
#
# patern: <num_rows, num_columns, num_channels>
# input shape: < 40 , 174 , 1 >
#
# filter size: 2

# %%
# COMPILING THE MODEL

# loss function: categorical_crossentropy

#model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='rmsprop') 
#model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer='adam') 
#model.compile(loss='mean_squared_error', metrics=['mean_absolute_error'], optimizer='adam')
#model.compile(loss='sparse_categorical_crossentropy', metrics=['sparse_categorical_accuracy'], optimizer='adam') 
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam') 

# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_38 (Conv2D)           (None, 39, 173, 16)       80
# _________________________________________________________________
# max_pooling2d_38 (MaxPooling (None, 19, 86, 16)        0
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 19, 86, 16)        0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 18, 85, 32)        2080
# _________________________________________________________________
# max_pooling2d_39 (MaxPooling (None, 9, 42, 32)         0
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 9, 42, 32)         0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 8, 41, 64)         8256
# _________________________________________________________________
# max_pooling2d_40 (MaxPooling (None, 4, 20, 64)         0
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 4, 20, 64)         0
# _________________________________________________________________
# global_average_pooling2d_10  (None, 64)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 3)                 195
# =================================================================
# Total params: 10,611
# Trainable params: 10,611
# Non-trainable params: 0
# _________________________________________________________________
# 4/4 [==============================] - 0s 9ms/step - loss: 3.1723 - accuracy: 0.3333
# Pre-training accuracy: 33.3333%

# %%
# CNN TRAINING

# if input is converging, it's good to set more ephocs

# val_loss starts increasing, val_acc starts decreasing. This means model is cramming values not learning
# val_loss starts increasing, val_acc also increases. This could be case of overfitting or 
#diverse probability values in cases where softmax is being used in output layer
# val_loss starts decreasing, val_acc starts increasing. This is also fine as that means model built is learning 
#and working fine.

# batch_size is god to set as 8, 16 32, 64, 128...
# batch size is the number of samples processed before the model is updated.
# The number of epochs is the number of complete passes through the training dataset.

from keras.callbacks import ModelCheckpoint 
from datetime import datetime 

# number of epochs
num_epochs = 20

# batch_size
# ex: i'm training 1000 samples. if batch_size = 100, the network will train 100 samples, then other 100...
# in the ex, we propagate 10 batches
# if use 1050 samples, you need to get the 50 final and train them (doing 11 batches)
# after each batch, the network updates parameters
# If we used all samples during propagation we would make only 1 update for the network's parameter

# Batch Gradient Descent. Batch Size = Size of Training Set
# Stochastic Gradient Descent. Batch Size = 1
# Mini-Batch Gradient Descent. 1 < Batch Size < Size of Training Set

num_batch_size = 64

# checkpoint for the model
checkpointer = ModelCheckpoint(filepath='./model_saved/checkpoints/{}_{}.hdf5'.format(num_batch_size, num_epochs), 
                               verbose=1, save_best_only=True)

# pick atual time to calculate time of training
start = datetime.now()

# train the model
#model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(x_test, y_test), callbacks=[checkpointer], verbose=1)
history = model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs, 
                    validation_data=(x_test, y_test), callbacks=[checkpointer], verbose=1)

# return training time
duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Epoch 1/20
# 7/8 [=========================>....] - ETA: 0s - loss: 2.3661 - accuracy: 0.3862
# Epoch 00001: val_loss improved from inf to 1.03702, saving model to ./model_saved/checkpoints/64_20.hdf5
# 8/8 [==============================] - 1s 88ms/step - loss: 2.3109 - accuracy: 0.3833 - val_loss: 1.0370 - val_accuracy: 0.3417
# Epoch 2/20
# 7/8 [=========================>....] - ETA: 0s - loss: 1.4877 - accuracy: 0.3504
# Epoch 00002: val_loss did not improve from 1.03702
# 8/8 [==============================] - 1s 86ms/step - loss: 1.4818 - accuracy: 0.3604 - val_loss: 1.1441 - val_accuracy: 0.6250
# Epoch 3/20
# 7/8 [=========================>....] - ETA: 0s - loss: 1.2729 - accuracy: 0.4219
# Epoch 00003: val_loss improved from 1.03702 to 0.92528, saving model to ./model_saved/checkpoints/64_20.hdf5
# 8/8 [==============================] - 1s 83ms/step - loss: 1.2636 - accuracy: 0.4229 - val_loss: 0.9253 - val_accuracy: 0.5417
# Epoch 4/20
# 7/8 [=========================>....] - ETA: 0s - loss: 1.0191 - accuracy: 0.4799
# Epoch 00004: val_loss improved from 0.92528 to 0.88599, saving model to ./model_saved/checkpoints/64_20.hdf5
# 8/8 [==============================] - 1s 83ms/step - loss: 1.0246 - accuracy: 0.4729 - val_loss: 0.8860 - val_accuracy: 0.5583
# Epoch 5/20
# 7/8 [=========================>....] - ETA: 0s - loss: 0.9198 - accuracy: 0.5156
# Epoch 00005: val_loss improved from 0.88599 to 0.77433, saving model to ./model_saved/checkpoints/64_20.hdf5
# 8/8 [==============================] - 1s 82ms/step - loss: 0.9227 - accuracy: 0.5250 - val_loss: 0.7743 - val_accuracy: 0.7917
# Epoch 6/20
# 8/8 [==============================] - ETA: 0s - loss: 0.8703 - accuracy: 0.5792
# Epoch 00006: val_loss improved from 0.77433 to 0.71791, saving model to ./model_saved/checkpoints/64_20.hdf5
# 8/8 [==============================] - 1s 87ms/step - loss: 0.8703 - accuracy: 0.5792 - val_loss: 0.7179 - val_accuracy: 0.7167
# Epoch 7/20
# 8/8 [==============================] - ETA: 0s - loss: 0.7346 - accuracy: 0.7146
# Epoch 00007: val_loss improved from 0.71791 to 0.67496, saving model to ./model_saved/checkpoints/64_20.hdf5
# 8/8 [==============================] - 1s 92ms/step - loss: 0.7346 - accuracy: 0.7146 - val_loss: 0.6750 - val_accuracy: 0.6750
# Epoch 8/20
# 7/8 [=========================>....] - ETA: 0s - loss: 0.7364 - accuracy: 0.6741
# Epoch 00008: val_loss improved from 0.67496 to 0.58021, saving model to ./model_saved/checkpoints/64_20.hdf5
# 8/8 [==============================] - 1s 85ms/step - loss: 0.7265 - accuracy: 0.6875 - val_loss: 0.5802 - val_accuracy: 0.9833
# Epoch 9/20
# 8/8 [==============================] - ETA: 0s - loss: 0.6224 - accuracy: 0.7312
# Epoch 00009: val_loss improved from 0.58021 to 0.53921, saving model to ./model_saved/checkpoints/64_20.hdf5
# 8/8 [==============================] - 1s 92ms/step - loss: 0.6224 - accuracy: 0.7312 - val_loss: 0.5392 - val_accuracy: 0.9333
# Epoch 10/20
# 7/8 [=========================>....] - ETA: 0s - loss: 0.5455 - accuracy: 0.7924
# Epoch 00010: val_loss improved from 0.53921 to 0.45004, saving model to ./model_saved/checkpoints/64_20.hdf5
# 8/8 [==============================] - 1s 87ms/step - loss: 0.5373 - accuracy: 0.7979 - val_loss: 0.4500 - val_accuracy: 0.9667
# Epoch 11/20
# 7/8 [=========================>....] - ETA: 0s - loss: 0.4631 - accuracy: 0.8549
# Epoch 00011: val_loss improved from 0.45004 to 0.38297, saving model to ./model_saved/checkpoints/64_20.hdf5
# 8/8 [==============================] - 1s 89ms/step - loss: 0.4632 - accuracy: 0.8562 - val_loss: 0.3830 - val_accuracy: 0.9750
# Epoch 12/20
# 8/8 [==============================] - ETA: 0s - loss: 0.4070 - accuracy: 0.8979
# Epoch 00012: val_loss improved from 0.38297 to 0.32664, saving model to ./model_saved/checkpoints/64_20.hdf5
# 8/8 [==============================] - 1s 95ms/step - loss: 0.4070 - accuracy: 0.8979 - val_loss: 0.3266 - val_accuracy: 0.9750
# Epoch 13/20
# 7/8 [=========================>....] - ETA: 0s - loss: 0.3334 - accuracy: 0.8996
# Epoch 00013: val_loss improved from 0.32664 to 0.27565, saving model to ./model_saved/checkpoints/64_20.hdf5
# 8/8 [==============================] - 1s 95ms/step - loss: 0.3311 - accuracy: 0.9021 - val_loss: 0.2756 - val_accuracy: 0.9917
# Epoch 14/20
# 8/8 [==============================] - ETA: 0s - loss: 0.2902 - accuracy: 0.9375
# Epoch 00014: val_loss improved from 0.27565 to 0.22118, saving model to ./model_saved/checkpoints/64_20.hdf5
# 8/8 [==============================] - 1s 91ms/step - loss: 0.2902 - accuracy: 0.9375 - val_loss: 0.2212 - val_accuracy: 1.0000
# Epoch 15/20
# 8/8 [==============================] - ETA: 0s - loss: 0.2469 - accuracy: 0.9333
# Epoch 00015: val_loss improved from 0.22118 to 0.17687, saving model to ./model_saved/checkpoints/64_20.hdf5
# 8/8 [==============================] - 1s 88ms/step - loss: 0.2469 - accuracy: 0.9333 - val_loss: 0.1769 - val_accuracy: 0.9917
# Epoch 16/20
# 8/8 [==============================] - ETA: 0s - loss: 0.2381 - accuracy: 0.9375
# Epoch 00016: val_loss improved from 0.17687 to 0.15116, saving model to ./model_saved/checkpoints/64_20.hdf5
# 8/8 [==============================] - 1s 94ms/step - loss: 0.2381 - accuracy: 0.9375 - val_loss: 0.1512 - val_accuracy: 1.0000
# Epoch 17/20
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1789 - accuracy: 0.9643
# Epoch 00017: val_loss improved from 0.15116 to 0.13071, saving model to ./model_saved/checkpoints/64_20.hdf5
# 8/8 [==============================] - 1s 86ms/step - loss: 0.1756 - accuracy: 0.9667 - val_loss: 0.1307 - val_accuracy: 1.0000
# Epoch 18/20
# 8/8 [==============================] - ETA: 0s - loss: 0.1587 - accuracy: 0.9708
# Epoch 00018: val_loss improved from 0.13071 to 0.11157, saving model to ./model_saved/checkpoints/64_20.hdf5
# 8/8 [==============================] - 1s 89ms/step - loss: 0.1587 - accuracy: 0.9708 - val_loss: 0.1116 - val_accuracy: 1.0000
# Epoch 19/20
# 8/8 [==============================] - ETA: 0s - loss: 0.1775 - accuracy: 0.9625
# Epoch 00019: val_loss improved from 0.11157 to 0.10640, saving model to ./model_saved/checkpoints/64_20.hdf5
# 8/8 [==============================] - 1s 89ms/step - loss: 0.1775 - accuracy: 0.9625 - val_loss: 0.1064 - val_accuracy: 1.0000
# Epoch 20/20
# 7/8 [=========================>....] - ETA: 0s - loss: 0.1643 - accuracy: 0.9509
# Epoch 00020: val_loss did not improve from 0.10640
# 8/8 [==============================] - 1s 90ms/step - loss: 0.1651 - accuracy: 0.9500 - val_loss: 0.1162 - val_accuracy: 0.9917
# Training completed in time:  0:00:16.797436

# %%
import matplotlib.pyplot as plt


# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# with keras, is possible to describe a model in JSON format 

# model_from_json (): create a new model based on JSON

from keras.models import model_from_json

model.summary()

# serialize model to JSON
model_json = model.to_json()
with open("./model_saved/model.json", "w") as json_file:
    json_file.write(model_json)
    
# serialize model in HDF5
model.save_weights("./model_saved/model.h5")
print("Modelo salvo!")
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_38 (Conv2D)           (None, 39, 173, 16)       80
# _________________________________________________________________
# max_pooling2d_38 (MaxPooling (None, 19, 86, 16)        0
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 19, 86, 16)        0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 18, 85, 32)        2080
# _________________________________________________________________
# max_pooling2d_39 (MaxPooling (None, 9, 42, 32)         0
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 9, 42, 32)         0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 8, 41, 64)         8256
# _________________________________________________________________
# max_pooling2d_40 (MaxPooling (None, 4, 20, 64)         0
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 4, 20, 64)         0
# _________________________________________________________________
# global_average_pooling2d_10  (None, 64)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 3)                 195
# =================================================================
# Total params: 10,611
# Trainable params: 10,611
# Non-trainable params: 0
# _________________________________________________________________
# Modelo salvo!
